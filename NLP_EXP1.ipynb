# %% [markdown]
# <a href="https://colab.research.google.com/github/konda-reddy13/NLP-EXP1/blob/main/NLP_EXP1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nltk

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
from nltk.tokenize import word_tokenize , sent_tokenize

# %%
input = "Hello I am konda reddy.How are you?"
output1 = word_tokenize(input)
print(output1)
output2 = sent_tokenize(input)
print(output2)
# Out:
# ['Hello', 'I', 'am', 'konda', 'reddy.How', 'are', 'you', '?']
# ['Hello I am konda reddy.How are you?']

# %%
input = "Hi"
output1 = word_tokenize(input)
print(output1)
output2 = sent_tokenize(input)
print(output2)
# Out:
# ['Hi']
# ['Hi']

# %%
# !pip install -U spacy

# %%
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 84.5 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
input = "Hi I am konda reddy. I"
doc = nlp(input)

# %%
for token in doc:
  print(token)
# Out:
# Hi
# I
# am
# konda
# reddy
# .
# I
